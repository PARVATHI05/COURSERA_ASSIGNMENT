# %% [markdown]
# ### CAPSTONE PROJECT

# %% [markdown]
# The problem I have chosen is to explore and compare the neighborhoods of Toronto and use this information in identifying a best location to open an restaurant in Downtown Toronto, where the population is highest.

# %%
import urllib.request
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# !pip install beautifulsoup4
from bs4 import BeautifulSoup as bs

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = urllib.request.urlopen(url)

# %%
soup = bs(page)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of postal codes of Canada: M - Wikipedia</title>
# ...

# %%
# Creating a Data Frame and saving table variable
df=pd.DataFrame(columns=['Postal Code','Borough','Neighborhood'])
table=soup.table

# %%
i=0
for tr in table.find_all('tr'): # Loop over 'tr' tags in the table
    try:
        td=tr.find_all('td') # Using 'td' tags
        
        if td[1].string.strip() != 'Not assigned': # Excluding 'Not assigned Borough'
            df.loc[i,'Postal Code'] = td[0].string.strip()
            df.loc[i,'Borough'] =  td[1].string.strip()
            
            if td[2].string.strip() == 'Not assigned': # Assigning Borough to 'Not assigned' Neighborhood
                df.loc[i,'Neighborhood'] =  td[1].string.strip()
            else:
                df.loc[i,'Neighborhood'] =  td[2].string.strip().replace('/',',') # Replaceing '/' to ','
                
            i+=1
        else:
            pass
    except:
        pass
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
# !pip install geopandas
# !pip install geopy
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
# Out:
# ...
#      |████████████████████████████████| 931kB 7.8MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 14.7MB 45.5MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.9MB 21.1MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.8MB 44.7MB/s eta 0:00:01
# ...

# %%
dfc=pd.read_csv("https://cocl.us/Geospatial_data")
dfc1=dfc.drop(['Postal Code'], axis=1)
dfc1
# Out:
#       Latitude  Longitude
# 0    43.806686 -79.194353
# 1    43.784535 -79.160497
# 2    43.763573 -79.188711
# 3    43.770992 -79.216917
# 4    43.773136 -79.239476
# 5    43.744734 -79.239476
# 6    43.727929 -79.262029
# 7    43.711112 -79.284577
# 8    43.716316 -79.239476
# 9    43.692657 -79.264848
# 10   43.757410 -79.273304
# 11   43.750072 -79.295849
# 12   43.794200 -79.262029
# 13   43.781638 -79.304302
# 14   43.815252 -79.284577
# 15   43.799525 -79.318389
# 16   43.836125 -79.205636
# 17   43.803762 -79.363452
# 18   43.778517 -79.346556
# 19   43.786947 -79.385975
# 20   43.757490 -79.374714
# 21   43.789053 -79.408493
# 22   43.770120 -79.408493
# 23   43.752758 -79.400049
# 24   43.782736 -79.442259
# 25   43.753259 -79.329656
# 26   43.745906 -79.352188
# 27   43.725900 -79.340923
# 28   43.754328 -79.442259
# 29   43.767980 -79.487262
# 30   43.737473 -79.464763
# 31   43.739015 -79.506944
# 32   43.728496 -79.495697
# 33   43.761631 -79.520999
# ...

# %%
dfh = pd.concat([df,dfc1], axis=1)
dfh
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
from geopy.geocoders import Nominatim
address = 'Toronto,Canada'
geolocator=Nominatim()
location=geolocator.geocode(address)
latitude=location.latitude
longitude=location.longitude
print('The coordinates of Toronto are {},{}.'.format(latitude,longitude))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.22.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# The coordinates of Toronto are 43.6534817,-79.3839347.

# %%
map_tor=folium.Map(location=[latitude,longitude],zoom_start=10)
for lat,lng,borough in zip(dfh['Latitude'],dfh['Longitude'],dfh['Borough']):
    label='{}'.format(borough)
    label=folium.Popup(label,parse_html=True)
    folium.CircleMarker([lat,lng],radius=5,popup=label, color='blue',fill=True,fill_color='#3186c',fill_opacity=0.7).add_to(map_tor)
map_tor
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df1 = dfh[dfh['Borough'].str.contains("Downtown Toronto")] 
df1
# Out:
#    Postal Code           Borough  \
# 2          M5A  Downtown Toronto
# 4          M7A  Downtown Toronto
# 9          M5B  Downtown Toronto
# 15         M5C  Downtown Toronto
# 20         M5E  Downtown Toronto
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 30         M5H  Downtown Toronto
# 36         M5J  Downtown Toronto
# 42         M5K  Downtown Toronto
# 48         M5L  Downtown Toronto
# 80         M5S  Downtown Toronto
# 84         M5T  Downtown Toronto
# 87         M5V  Downtown Toronto
# 91         M4W  Downtown Toronto
# 92         M5W  Downtown Toronto
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 99         M4Y  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 2                           Regent Park, Harbourfront  43.763573 -79.188711
# 4         Queen's Park, Ontario Provincial Government  43.773136 -79.239476
# ...

# %%
map_dt=folium.Map(location=[latitude,longitude],zoom_start=11)
for lat,lng,label in zip(df1['Latitude'],df1['Longitude'],df1['Neighborhood']):
    label=folium.Popup(label,parse_html=True)
    folium.CircleMarker([lat,lng],radius=5,popup=label, color='blue',fill=True,fill_color='#3186c',fill_opacity=0.7).add_to(map_dt)
map_dt
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
results = requests.get(url).json()

venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
nearby_venues.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-42df5139315f> in <module>
#       1 results = requests.get(url).json()
#       2
# ----> 3 venues = results['response']['groups'][0]['items']
#       4 nearby_venues = json_normalize(venues) # flatten JSON
#       5
#
# KeyError: 'groups'

# %%
nearby_venues.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-6df1bd971cc0> in <module>
# ----> 1 nearby_venues.shape
#
# NameError: name 'nearby_venues' is not defined

# %%
nearby_venues['name'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-92da26d82f13> in <module>
# ----> 1 nearby_venues['name'].value_counts()
#
# NameError: name 'nearby_venues' is not defined

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-8d3c8155afff> in <module>
# ----> 1 print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
#
# NameError: name 'nearby_venues' is not defined

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, CLIENT_SECRET, 
            VERSION, lat, lng, radius, LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, lat, lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 'Neighborhood Latitude', 'Neighborhood Longitude', 
                             'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category']
    
    return(nearby_venues)

# %%
tor_venues = getNearbyVenues(names=dfh['Neighborhood'],
                                   latitudes=dfh['Latitude'],
                                   longitudes=dfh['Longitude']
                                  )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-ac8c0ce60aaf> in <module>
#       1 tor_venues = getNearbyVenues(names=dfh['Neighborhood'],
#       2                                    latitudes=dfh['Latitude'],
# ----> 3                                    longitudes=dfh['Longitude']
#       4                                   )
#
# <ipython-input-67-af3f9b2b11b4> in getNearbyVenues(names, latitudes, longitudes, radius)
#       8
#       9         # make the GET request
# ---> 10         results = requests.get(url).json()["response"]['groups'][0]['items']
#      11
#      12         # return only relevant information for each nearby venue
#
# KeyError: 'groups'

# %%
tor_venues.groupby('Neighborhood').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-2da6f4b85572> in <module>
# ----> 1 tor_venues.groupby('Neighborhood').count()
#
# NameError: name 'tor_venues' is not defined

# %%
print('There are {} uniques categories.'.format(len(Newham_venues['Venue Category'].unique())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-43f664312339> in <module>
# ----> 1 print('There are {} uniques categories.'.format(len(Newham_venues['Venue Category'].unique())))
#
# NameError: name 'Newham_venues' is not defined

# %%
tor_onehot = pd.get_dummies(tor_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
tor_onehot['Neighborhood'] = tor_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [tor_onehot.columns[-1]] + list(tor_onehot.columns[:-1])
tor_onehot = tor_onehot[fixed_columns]

tor_onehot.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-808e397ba7c4> in <module>
# ----> 1 tor_onehot = pd.get_dummies(tor_venues[['Venue Category']], prefix="", prefix_sep="")
#       2
#       3 # add neighborhood column back to dataframe
#       4 tor_onehot['Neighborhood'] = tor_venues['Neighborhood']
#       5
#
# NameError: name 'tor_venues' is not defined

# %%
tor_grouped =tor_onehot.groupby('Neighborhood').mean().reset_index()
tor_grouped.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-486fb2b2a9df> in <module>
#       1
# ----> 2 tor_grouped =tor_onehot.groupby('Neighborhood').mean().reset_index()
#       3 tor_grouped.head()
#
# NameError: name 'tor_onehot' is not defined

# %%
Newham_grouped.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-8e58f879f59a> in <module>
# ----> 1 Newham_grouped.columns
#
# NameError: name 'Newham_grouped' is not defined

# %%
num_top_venues = 5
for hood in tor_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = tor_grouped[tor_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-26ae5e4d7049> in <module>
#       1 num_top_venues = 5
# ----> 2 for hood in tor_grouped['Neighborhood']:
#       3     print("----"+hood+"----")
#       4     temp = tor_grouped[tor_grouped['Neighborhood'] == hood].T.reset_index()
#       5     temp.columns = ['venue','freq']
#
# NameError: name 'tor_grouped' is not defined

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
        
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = tor_grouped['Neighborhood']

for ind in np.arange(tor_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(tor_grouped.iloc[ind, :], num_top_venues)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-fb356d8b7238> in <module>
#      12 # create a new dataframe
#      13 neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
# ---> 14 neighborhoods_venues_sorted['Neighborhood'] = tor_grouped['Neighborhood']
#      15
#      16 for ind in np.arange(tor_grouped.shape[0]):
#
# NameError: name 'tor_grouped' is not defined

# %%
neighborhoods_venues_sorted.head()
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
tor_grouped.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-5ceceb56fd71> in <module>
# ----> 1 tor_grouped.head()
#
# NameError: name 'tor_grouped' is not defined

# %%
# set number of clusters
kclusters = 5
tor_grouped_clustering = tor_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(tor_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-9c743e8f5612> in <module>
#       1 # set number of clusters
#       2 kclusters = 5
# ----> 3 tor_grouped_clustering = tor_grouped.drop('Neighborhood', 1)
#       4
#       5 # run k-means clustering
#
# NameError: name 'tor_grouped' is not defined

# %%
tor_merged = tor_borough
# add clustering labels
tor_merged['Cluster Labels'] = kmeans.labels_

# merge Neighborhoods dataframe with Newham borough dataframe to add latitude/longitude for each neighborhood
tormerged = tor_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

tor_merged.head() # check the last columns!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-1acc6395382c> in <module>
# ----> 1 tor_merged = tor_borough
#       2 # add clustering labels
#       3 tor_merged['Cluster Labels'] = kmeans.labels_
#       4
#       5 # merge Neighborhoods dataframe with Newham borough dataframe to add latitude/longitude for each neighborhood
#
# NameError: name 'tor_borough' is not defined

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
y = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(y)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(tor_merged['Latitude'], tor_merged['Longitude'], tor_merged['Neighborhood'], tor_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-9b039502247c> in <module>
#      10 # add markers to the map
#      11 markers_colors = []
# ---> 12 for lat, lon, poi, cluster in zip(tor_merged['Latitude'], tor_merged['Longitude'], tor_merged['Neighborhood'], tor_merged['Cluster Labels']):
#      13     label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
#      14     folium.CircleMarker(
#
# NameError: name 'tor_merged' is not defined

# %%
tor_merged.loc[tor_merged['Cluster Labels'] == 0, tor_merged.columns[[1] + list(range(5, tor_merged.shape[1]))]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-d5b9952c94a9> in <module>
# ----> 1 tor_merged.loc[tor_merged['Cluster Labels'] == 0, tor_merged.columns[[1] + list(range(5, tor_merged.shape[1]))]]
#
# NameError: name 'tor_merged' is not defined
